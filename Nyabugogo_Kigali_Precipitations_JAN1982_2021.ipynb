# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('C:/Users/Papa/Documents/Nyabugogo_Kigali_Daily_Dataset/Nyabugogo_Kigali_Daily_PREC_JAN1982_JAN2021.csv')
data.head()
# Out:
#    DAY   1982  1983  1984  1985  1986   1987  1988  1989   1990  ...  2012  \
# 0    1  11.62  2.30  2.72  0.74  5.17   1.48  2.23  3.41  12.89  ...  0.05
# 1    2   7.66  1.18  0.29  2.63  1.35  11.48  3.67  5.07   7.81  ...  0.00
# 2    3  10.69  1.91  1.70  3.93  0.48   3.32  1.53  9.41   3.45  ...  0.01
# 3    4   4.95  4.59  0.12  0.63  1.39   3.34  1.20  6.97   4.47  ...  0.02
# 4    5   2.31  1.72  3.87  0.07  1.50   2.67  2.26  6.52   4.72  ...  0.03
#
#    2013  2014  2015  2016  2017   2018  2019   2020   2021
# 0  1.89  1.25  4.76  0.37  5.61   2.46  6.04   1.66  27.01
# 1  3.51  0.35  0.30  0.27  0.95  14.79  0.15   1.62   2.65
# 2  1.54  0.37  0.23  0.23  1.00  47.69  0.22   0.76   1.33
# 3  0.10  0.11  0.61  0.24  0.24   3.41  1.53  29.49   2.37
# 4  1.78  0.16  4.49  1.12  0.10   7.08  4.21   2.49   3.78
#
# [5 rows x 41 columns]

# %%
data.tail()
# Out:
#     DAY  1982  1983  1984  1985  1986   1987  1988  1989  1990  ...  2012  \
# 26   27  0.12  0.12  2.33  4.87  0.52   5.10  0.89  5.89  0.83  ...  0.00
# 27   28  0.51  0.09  0.88  2.28  0.63   4.42  3.31  0.10  0.64  ...  0.00
# 28   29  0.21  0.19  0.62  2.36  0.64  11.93  3.63  2.59  0.80  ...  0.00
# 29   30  1.00  0.05  3.77  1.32  0.26   9.73  0.50  2.06  3.01  ...  0.02
# 30   31  4.65  0.45  0.49  2.62  2.72  19.12  1.46  1.07  5.90  ...  0.01
#
#      2013  2014  2015  2016  2017  2018  2019   2020  2021
# 26   4.08  5.92  0.46  1.28  1.68  1.31  0.96   4.94  0.71
# 27   7.64  3.08  2.71  0.90  3.32  1.42  1.02  31.91  0.60
# 28   2.88  1.85  5.62  0.03  6.07  0.78  2.64   6.70  0.42
# 29  11.39  1.26  2.81  0.00  2.98  1.36  3.14   2.95  3.65
# 30   4.15  0.52  0.13  0.73  7.15  0.12  0.35   3.09  1.87
#
# [5 rows x 41 columns]

# %%
#check for missing data in pandas dataframe
#print(data.isnull())

# %%
#data.info()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(data['DAY'], data['1982'], color='green', label='Daily Precipitations')
ax.set_xticks(range(0, 31, 1))
ax.set_xlabel('Day January1982')
ax.set_ylabel('Daily Precipitations')
ax.legend()
plt.show()

# %%
# Create a line plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(data['DAY'], data['1982'], color='green', label='Daily Precipitations')
# Set x-ticks
ax.set_xticks(range(0, 31, 1))
# Set labels and title
ax.set_xlabel('Day January1982')
ax.set_ylabel('Daily Precipitations')
# Add legend
ax.legend()
# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(data['DAY'], data['1982'], color='green', label='Daily Precipitations')
ax.set_xticks(range(0, 31, 1))
ax.set_xlabel('Day January1982')
ax.set_ylabel('Daily Precipitations')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(data['DAY'], data['1982'], color='black', label='1982')
ax.scatter(data['DAY'], data['1983'], color='blue', label='1983')
ax.scatter(data['DAY'], data['1984'], color='green', label='1984')
ax.scatter(data['DAY'], data['1985'], color='red', label='1985')
ax.scatter(data['DAY'], data['1986'], color='purple', label='1986')
ax.scatter(data['DAY'], data['1987'], color='orange', label='1987')
ax.scatter(data['DAY'], data['1988'], color='brown', label='1988')
ax.scatter(data['DAY'], data['1989'], color='pink', label='1989')
ax.scatter(data['DAY'], data['1990'], color='gray', label='1990')
ax.scatter(data['DAY'], data['1991'], color='cyan', label='1991')
ax.scatter(data['DAY'], data['1992'], color='magenta', label='1992')
ax.scatter(data['DAY'], data['1993'], color='yellow', label='1993')
ax.set_xticks(range(0, 32, 1))
ax.set_xlabel('Date')
ax.set_title('Nyabugogo_Kigali Daily Precipitations 1982-1993')
ax.set_ylabel('Monthly Average Precipitations')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(data['DAY'], data['1982'], color='black', label='1982')
ax.plot(data['DAY'], data['1983'], color='blue', label='1983')
ax.plot(data['DAY'], data['1984'], color='green', label='1984')
ax.plot(data['DAY'], data['1985'], color='red', label='1985')
ax.plot(data['DAY'], data['1986'], color='purple', label='1986')
ax.plot(data['DAY'], data['1987'], color='orange', label='1987')
ax.plot(data['DAY'], data['1988'], color='brown', label='1988')
ax.plot(data['DAY'], data['1989'], color='pink', label='1989')
ax.plot(data['DAY'], data['1990'], color='gray', label='1990')
ax.plot(data['DAY'], data['1991'], color='cyan', label='1991')
ax.plot(data['DAY'], data['1992'], color='magenta', label='1992')
ax.plot(data['DAY'], data['1993'], color='yellow', label='1993')
ax.set_xticks(range(0, 32, 1))
ax.set_xlabel('Date')
ax.set_title('Nyabugogo_Kigali Daily Precipitations 1982-1993')
ax.set_ylabel('Monthly Average Precipitations')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(data['DAY'], data['1994'], color='black', label='1994')
ax.plot(data['DAY'], data['1995'], color='blue', label='1995')
ax.plot(data['DAY'], data['1996'], color='green', label='1996')
ax.plot(data['DAY'], data['1997'], color='red', label='1997')
ax.plot(data['DAY'], data['1998'], color='purple', label='1998')
ax.plot(data['DAY'], data['1999'], color='orange', label='1999')
ax.plot(data['DAY'], data['2000'], color='brown', label='2000')
ax.plot(data['DAY'], data['2001'], color='pink', label='2001')
ax.plot(data['DAY'], data['2002'], color='gray', label='2002')
ax.plot(data['DAY'], data['2003'], color='cyan', label='2003')
ax.plot(data['DAY'], data['2004'], color='magenta', label='2004')
ax.plot(data['DAY'], data['2005'], color='yellow', label='2005')
ax.set_xticks(range(0, 32, 1))
ax.set_xlabel('Date')
ax.set_title('Nyabugogo_Kigali Daily Precipitations 1994-2005')
ax.set_ylabel('Monthly Average Precipitations')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(data['DAY'], data['2006'], color='black', label='2006')
ax.plot(data['DAY'], data['2007'], color='blue', label='2007')
ax.plot(data['DAY'], data['2008'], color='green', label='2008')
ax.plot(data['DAY'], data['2009'], color='red', label='2009')
ax.plot(data['DAY'], data['2010'], color='purple', label='2010')
ax.plot(data['DAY'], data['2011'], color='orange', label='2011')
ax.plot(data['DAY'], data['2012'], color='brown', label='2012')
ax.plot(data['DAY'], data['2013'], color='pink', label='2013')
ax.plot(data['DAY'], data['2014'], color='gray', label='2014')
ax.plot(data['DAY'], data['2015'], color='cyan', label='2015')
ax.plot(data['DAY'], data['2016'], color='magenta', label='2016')
ax.plot(data['DAY'], data['2017'], color='yellow', label='2017')
ax.plot(data['DAY'], data['2018'], color='silver', label='2018')
ax.plot(data['DAY'], data['2019'], color='maroon', label='2019')
ax.plot(data['DAY'], data['2020'], color='teal', label='2020')
ax.plot(data['DAY'], data['2021'], color='lime', label='2021')
ax.set_xticks(range(0, 32, 1))
ax.set_xlabel('Date')
ax.set_title('Nyabugogo_Kigali Daily Precipitations 1994-2005')
ax.set_ylabel('Monthly Average Precipitations')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
#basic statistics of a dataset
data.describe()
# Out:
#              DAY       1982       1983       1984       1985       1986  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean   16.000000   3.172258   0.928387   1.943226   2.389355   2.277419
# std     9.092121   3.153613   1.080645   1.467638   2.464319   2.063977
# min     1.000000   0.020000   0.040000   0.120000   0.010000   0.160000
# 25%     8.500000   0.780000   0.125000   0.830000   0.340000   0.970000
# 50%    16.000000   2.170000   0.450000   1.660000   2.140000   1.530000
# 75%    23.500000   4.290000   1.285000   2.725000   3.825000   2.645000
# max    31.000000  11.620000   4.590000   6.370000  11.280000   9.310000
#
#             1987       1988       1989       1990  ...       2012       2013  \
# count  31.000000  31.000000  31.000000  31.000000  ...  31.000000  31.000000
# mean    4.477419   2.327419   2.492903   2.395806  ...   0.458065   2.000000
# std     4.114192   1.516962   2.328442   3.111560  ...   0.934739   2.413859
# ...

# %%
#basic statistics of a dataset except column DAY
data_except_columnDAY = data.iloc[:,1:]
data_except_columnDAY.describe()
# Out:
#             1982       1983       1984       1985       1986       1987  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean    3.172258   0.928387   1.943226   2.389355   2.277419   4.477419
# std     3.153613   1.080645   1.467638   2.464319   2.063977   4.114192
# min     0.020000   0.040000   0.120000   0.010000   0.160000   0.160000
# 25%     0.780000   0.125000   0.830000   0.340000   0.970000   2.150000
# 50%     2.170000   0.450000   1.660000   2.140000   1.530000   3.450000
# 75%     4.290000   1.285000   2.725000   3.825000   2.645000   4.830000
# max    11.620000   4.590000   6.370000  11.280000   9.310000  19.120000
#
#             1988       1989       1990       1991  ...       2012       2013  \
# count  31.000000  31.000000  31.000000  31.000000  ...  31.000000  31.000000
# mean    2.327419   2.492903   2.395806   1.871935  ...   0.458065   2.000000
# std     1.516962   2.328442   3.111560   1.969031  ...   0.934739   2.413859
# ...
